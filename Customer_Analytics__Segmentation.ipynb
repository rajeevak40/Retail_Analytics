# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeevak40/Retail_Analytics/blob/main/Customer_Analytics__Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Topic : Customer Analytics
#  Objective of this project is to pickup real time retail data and analyse the historical data and try to predict certain key ascpects.

# %%
# Importing key liberaies
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.decomposition import PCA
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import data set and analysis

# %%
# Loading data
df=pd.read_csv('/content/segmentation data.xls', index_col=0)

# %%
df.head()
# Out:
#            Sex  Marital status  Age  ...  Income  Occupation  Settlement size
# ID                                   ...
# 100000001    0               0   67  ...  124670           1                2
# 100000002    1               1   22  ...  150773           1                2
# 100000003    0               0   49  ...   89210           0                0
# 100000004    0               0   45  ...  171565           1                1
# 100000005    0               0   53  ...  149031           1                1
#
# [5 rows x 7 columns]

# %%
df.describe()
# Out:
#                Sex  Marital status  ...   Occupation  Settlement size
# count  2000.000000     2000.000000  ...  2000.000000      2000.000000
# mean      0.457000        0.496500  ...     0.810500         0.739000
# std       0.498272        0.500113  ...     0.638587         0.812533
# min       0.000000        0.000000  ...     0.000000         0.000000
# 25%       0.000000        0.000000  ...     0.000000         0.000000
# 50%       0.000000        0.000000  ...     1.000000         1.000000
# 75%       1.000000        1.000000  ...     1.000000         1.000000
# max       1.000000        1.000000  ...     2.000000         2.000000
#
# [8 rows x 7 columns]

# %%
#Pearson Correlation of varibales
df.corr()
# Out:
#                       Sex  Marital status  ...  Occupation  Settlement size
# Sex              1.000000        0.566511  ...   -0.202491        -0.300803
# Marital status   0.566511        1.000000  ...   -0.029490        -0.097041
# Age             -0.182885       -0.213178  ...    0.108388         0.119751
# Education        0.244838        0.374017  ...    0.064524         0.034732
# Income          -0.195146       -0.073528  ...    0.680357         0.490881
# Occupation      -0.202491       -0.029490  ...    1.000000         0.571795
# Settlement size -0.300803       -0.097041  ...    0.571795         1.000000
#
# [7 rows x 7 columns]

# %%
# Plotting them on head map
plt.figure(figsize=(10,12))
sns.heatmap(df.corr(), 
            annot=True,
            vmin=-1, vmax=1,
            cmap='RdBu')
plt.title('Correlation HeatMap')
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(10,12))
plt.scatter(df.iloc[:,2], df.iloc[:,4])
plt.xlabel('Age')
plt.ylabel('Income')
plt.title("Plotting Age Vs Income")
plt.show()

# %% [markdown]
# # Standardization of Data
# Inorder the give equal weight for all the varibale it is important to do standarize the varibels and keep them in same range.

# %%
scaler= StandardScaler()
std_df= scaler.fit_transform(df)
std_df
# Out:
# array([[-0.91739884, -0.99302433,  2.65361447, ...,  0.09752361,
#          0.29682303,  1.552326  ],
#        [ 1.09003844,  1.00702467, -1.18713209, ...,  0.78265438,
#          0.29682303,  1.552326  ],
#        [-0.91739884, -0.99302433,  1.11731585, ..., -0.83320224,
#         -1.26952539, -0.90972951],
#        ...,
#        [-0.91739884, -0.99302433, -0.41898277, ..., -0.90695688,
#         -1.26952539, -0.90972951],
#        [ 1.09003844,  1.00702467, -1.01643224, ..., -0.60332923,
#         -1.26952539, -0.90972951],
#        [-0.91739884, -0.99302433, -0.93108232, ..., -1.3789866 ,
#         -1.26952539, -0.90972951]])

# %% [markdown]
# # Hierarchical Clustering
#
# Clusting can be devisive (top down) or Agglomerative ( Bottoms up).

# %%
df_h_cluster=linkage(std_df, method='ward')

# %%
plt.figure(figsize=(10,12))
plt.title(' Hierarcical Clustering Dendorgram')
plt.xlabel('Observations')
plt.ylabel('Distance')
dendrogram(df_h_cluster, show_leaf_counts=False,no_labels=True, truncate_mode='level', p=5 )
plt.show()

# %% [markdown]
# # K-Means Clustering
#
# Most commonly used clustering method.

# %%
#KMean computation
wcss=[]
for i in range(1,11):
  kmeans=KMeans(n_clusters=i, init= 'k-means++', random_state=42)
  kmeans.fit(std_df)
  wcss.append(kmeans.inertia_)

# %%
# Line Plot
plt.figure(figsize=(10,9))
plt.plot(wcss, marker="o", linestyle='-', )
plt.xlabel(' # of Clusters')
plt.ylabel('WCSS')
plt.title("K Mean Cluster")
plt.show()

# %%
kmeans=KMeans(n_clusters=4, init= 'k-means++', random_state=42)
kmeans.fit(std_df)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
df_kmean= df.copy()
df_kmean['KMean_Segment']= kmeans.labels_

# %%
kMean_analysis=df_kmean.groupby(['KMean_Segment']).mean()
kMean_analysis
# Out:
#                     Sex  Marital status  ...  Occupation  Settlement size
# KMean_Segment                            ...
# 0              0.501901        0.692015  ...    1.129278         1.110266
# 1              0.352814        0.019481  ...    0.329004         0.043290
# 2              0.853901        0.997163  ...    0.634043         0.422695
# 3              0.029825        0.173684  ...    1.271930         1.522807
#
# [4 rows x 7 columns]

# %%
kMean_analysis['No_of_Observ']= df_kmean[['KMean_Segment', 'Sex']].groupby(['KMean_Segment']).count()
kMean_analysis['%_of Observ']= kMean_analysis['No_of_Observ']/kMean_analysis['No_of_Observ'].sum()

# %%
kMean_analysis
# Out:
#                     Sex  Marital status  ...  No_of_Observ  %_of Observ
# KMean_Segment                            ...
# 0              0.501901        0.692015  ...           263       0.1315
# 1              0.352814        0.019481  ...           462       0.2310
# 2              0.853901        0.997163  ...           705       0.3525
# 3              0.029825        0.173684  ...           570       0.2850
#
# [4 rows x 9 columns]

# %%
# Renaming Segments with correct classes
kMean_analysis.rename({0: 'Well_off', 1:'Few_Oppertunities', 2:'Standard', 3:'Career_Focused'})
# Out:
#                         Sex  Marital status  ...  No_of_Observ  %_of Observ
# KMean_Segment                                ...
# Well_off           0.501901        0.692015  ...           263       0.1315
# Few_Oppertunities  0.352814        0.019481  ...           462       0.2310
# Standard           0.853901        0.997163  ...           705       0.3525
# Career_Focused     0.029825        0.173684  ...           570       0.2850
#
# [4 rows x 9 columns]

# %%
df_kmean['Lables']=df_kmean['KMean_Segment'].map({0: 'Well_off', 1:'Few_Oppertunities', 2:'Standard', 3:'Career_Focused'})

# %%
# Plotting the cluster on scattered plot in order to visualise.
x_axis = df_kmean['Age']
y_axis= df_kmean['Income']
plt.figure(figsize=(10,9))
sns.scatterplot(x_axis, y_axis,hue=df_kmean['Lables'],palette=['r', 'b', 'g', 'y'])
plt.title("Segementation using KMean clustering")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Using Principal Component Analysis (PCA)
#
# PCA is one of the menthod in dimensionality reduction. This helps in improving our accurancy in cluster creation.

# %%
pca= PCA()

# %%
pca.fit(std_df)
# Out:
# PCA()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114, 0.0755775 , 0.05716512,
#        0.03954794, 0.02002579])

# %%
plt.figure(figsize=(12,9))
plt.plot(range(1,8), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle='--')
plt.title('Explained Varianble by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
# PCA with 3 component
pca_3= PCA(n_components=3)
pca_3.fit(std_df)
pca_3.explained_variance_ratio_
# Out:
# array([0.35696328, 0.26250923, 0.18821114])

# %%
df.head()
# Out:
#            Sex  Marital status  Age  ...  Income  Occupation  Settlement size
# ID                                   ...
# 100000001    0               0   67  ...  124670           1                2
# 100000002    1               1   22  ...  150773           1                2
# 100000003    0               0   49  ...   89210           0                0
# 100000004    0               0   45  ...  171565           1                1
# 100000005    0               0   53  ...  149031           1                1
#
# [5 rows x 7 columns]

# %%
pca3_comp =pd.DataFrame(data=pca_3.components_, index=['Component-1', 'Component-2', 'Component-3'], columns=df.columns)
pca3_comp
# Out:
#                   Sex  Marital status  ...  Occupation  Settlement size
# Component-1 -0.314695       -0.191704  ...    0.492059         0.464789
# Component-2  0.458006        0.512635  ...    0.014658        -0.069632
# Component-3 -0.293013       -0.441977  ...   -0.395505        -0.295685
#
# [3 rows x 7 columns]

# %%
#plt.figure(figsize=(12,12))
sns.heatmap(pca3_comp, vmin=-1, vmax=1, cmap='RdBu',annot=True)
plt.show()

# %%
pca_score=pca_3.transform(std_df)
pca_score.shape
# Out:
# (2000, 3)

# %%
# K-Means Clustering based on PCA
# KMean computation
wcss=[]
for i in range(1,11):
  kmeans=KMeans(n_clusters=i, init= 'k-means++', random_state=42)
  kmeans.fit(pca_score)
  wcss.append(kmeans.inertia_)

# Line Plot
plt.figure(figsize=(10,9))
plt.plot(wcss, marker="o", linestyle='-', )
plt.xlabel(' # of Clusters')
plt.ylabel('WCSS')
plt.title("K Mean Cluster Based on PCA")
plt.show()

# %% [markdown]
# # KMEANS PCA Model with 4 Cluster

# %%
kmeans_pca_3 = KMeans(n_clusters=4, init='k-means++', random_state=42)
kmeans_pca_3.fit(pca_score)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
df_segm_pca_kmeans=pd.concat([df.reset_index(drop=True), pd.DataFrame(pca_score)],axis=1)
df_segm_pca_kmeans.columns.values[-3:]=['Component 1', 'Component 2', 'Component 3']
df_segm_pca_kmeans['Segment K-Means PCA']=kmeans_pca_3.labels_

# %%
df_segm_pca_kmeans.head()
# Out:
#    Sex  Marital status  Age  ...  Component 2  Component 3  Segment K-Means PCA
# 0    0               0   67  ...     0.834122     2.174806                    3
# 1    1               1   22  ...     0.598146    -2.211603                    0
# 2    0               0   49  ...    -0.680093     2.280419                    2
# 3    0               0   45  ...    -0.579927     0.730731                    1
# 4    0               0   53  ...    -0.440496     1.244909                    1
#
# [5 rows x 11 columns]

# %%
df_segm_pca_kmeans_freq= df_segm_pca_kmeans.groupby(['Segment K-Means PCA']).mean()
df_segm_pca_kmeans_freq= df_segm_pca_kmeans_freq.rename({0:'Standard', 1:'Career Focused', 2:'Fewer Oppty', 3:'Well-Off'})
df_segm_pca_kmeans_freq
# Out:
#                           Sex  Marital status  ...  Component 2  Component 3
# Segment K-Means PCA                            ...
# Standard             0.900289        0.965318  ...     0.703776    -0.781410
# Career Focused       0.027444        0.168096  ...    -1.046172    -0.248046
# Fewer Oppty          0.306522        0.095652  ...    -0.902963     1.003644
# Well-Off             0.505660        0.690566  ...     2.031200     0.844039
#
# [4 rows x 10 columns]

# %%
df_segm_pca_kmeans['Legend']= df_segm_pca_kmeans['Segment K-Means PCA'].map({0:'Standard', 1:'Career Focused', 2:'Fewer Oppty', 3:'Well-Off'})
df_segm_pca_kmeans.head()
# Out:
#    Sex  Marital status  Age  ...  Component 3  Segment K-Means PCA          Legend
# 0    0               0   67  ...     2.174806                    3        Well-Off
# 1    1               1   22  ...    -2.211603                    0        Standard
# 2    0               0   49  ...     2.280419                    2     Fewer Oppty
# 3    0               0   45  ...     0.730731                    1  Career Focused
# 4    0               0   53  ...     1.244909                    1  Career Focused
#
# [5 rows x 12 columns]

# %%
x_axis=df_segm_pca_kmeans['Component 2']
y_axis=df_segm_pca_kmeans['Component 1']
plt.figure(figsize=(10,8))
sns.scatterplot(x_axis, y_axis, hue=df_segm_pca_kmeans['Legend'], palette=['g','r','b','m'])
plt.title('Clusters by PCA Components')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Save Model to a file

# %%
# Export Scaler
pickle.dump(scaler, open('scaler.pickle', 'wb'))

# Export PCA
pickle.dump(pca_3, open('pca.pickle', 'wb'))

# KMean PCA
pickle.dump(kmeans_pca_3, open('kmean_pca.pickle', 'wb'))
